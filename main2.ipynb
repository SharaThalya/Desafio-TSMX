# %%
import pandas as pd
import psycopg2 


conn = psycopg2.connect(
    host="localhost",
    dbname="db_des_tsmx",
    user="postgres",
    password="postgres"
)

cursor = conn.cursor()

# %%
df = pd.read_excel("C:/Users/jluca/Downloads/dados_importacao.xlsx", engine="openpyxl")
df.head(10)
# Out:
#       Nome/Razão Social Nome Fantasia        CPF/CNPJ Data Nasc.  \
# 0          Nicolas Melo           NaN  591.267.843-19 1982-03-16
# 1         Igor Silveira           NaN  102.694.758-85 1975-04-26
# 2       Henrique da Luz           NaN  782.531.904-41 1997-06-17
# 3     Valentina da Mota           NaN  865.902.374-92        NaT
# 4   Giovanna Cavalcanti           NaN  173.598.642-91 1964-11-30
# 5          Theo da Rosa           NaN  052.941.638-70 1966-02-28
# 6    Srta. Ana Ferreira           NaN  673.129.584-19 1992-04-07
# 7     Mariana Rodrigues           NaN  384.510.769-39        NaT
# 8     Sr. Renan Freitas           NaN  597.106.234-43 1917-03-27
# 9  Larissa da Conceição           NaN  025.873.946-00        NaT
#
#   Data Cadastro cliente     Celulares     Telefones  \
# 0            2023-01-02           NaN  5.581004e+12
# 1            2022-10-25  5.571677e+12           NaN
# 2            2022-10-11  5.511484e+12  5.531980e+12
# ...
